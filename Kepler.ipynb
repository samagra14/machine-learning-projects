# %%
KEPLER_PATH = "datasets/kepler"
import pandas as pd
def load_housing_data(housing_path=KEPLER_PATH):
    csv_path = os.path.join(housing_path, "ExoTrain.csv")
    return pd.read_csv(csv_path)

# %%
import os
kepler = load_housing_data()

# %%
kepler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Columns: 3198 entries, LABEL to FLUX.3197
# dtypes: float64(3197), int64(1)
# memory usage: 96.6 MB

# %%
kepler.describe()
# Out:
#              LABEL         FLUX.1         FLUX.2         FLUX.3  \
# count  3960.000000    3960.000000    3960.000000    3960.000000
# mean      1.008333     -95.957018     -63.100912     -89.827429
# std       0.090917    5379.590354    5124.130820    5007.125786
# min       1.000000 -216192.000000 -219338.000000 -212822.000000
# 25%       1.000000     -40.877500     -38.012500     -37.037500
# 50%       1.000000      -0.605000      -1.035000      -1.000000
# 75%       1.000000      50.275000      45.227500      44.782500
# max       2.000000  150725.800000  129578.360000  102184.980000
#
#               FLUX.4         FLUX.5         FLUX.6         FLUX.7  \
# count    3960.000000    3960.000000    3960.000000    3960.000000
# mean      -85.076212    -131.238222    -128.423841    -161.990629
# std      5315.021226    5817.851500    6704.807347    7174.806624
# min   -217468.000000 -221268.000000 -292749.390000 -338450.030000
# ...

# %%
target = kepler["LABEL"]

# %%
data = kepler[1:]

# %%
data.describe()
# Out:
#              LABEL         FLUX.1         FLUX.2         FLUX.3  \
# count  3959.000000    3959.000000    3959.000000    3959.000000
# mean      1.008083     -95.971435     -63.108305     -89.835332
# std       0.089552    5380.269819    5124.778071    5007.758254
# min       1.000000 -216192.000000 -219338.000000 -212822.000000
# 25%       1.000000     -40.885000     -38.055000     -36.980000
# 50%       1.000000      -0.600000      -1.030000      -1.000000
# 75%       1.000000      50.330000      45.235000      44.845000
# max       2.000000  150725.800000  129578.360000  102184.980000
#
#               FLUX.4         FLUX.5         FLUX.6         FLUX.7  \
# count    3959.000000    3959.000000    3959.000000    3959.000000
# mean      -85.087575    -131.251339    -128.437888    -162.009684
# std      5315.692563    5818.586343    6705.654230    7175.712834
# min   -217468.000000 -221268.000000 -292749.390000 -338450.030000
# ...

# %%
target.describe()
# Out:
# count    3960.000000
# mean        1.008333
# std         0.090917
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: LABEL, dtype: float64
